# %% [markdown]
# # RFM Analysis Homework
#
# ## Objective
# Apply RFM segmentation to the provided sales data and create actionable customer segments.
#
# ## Datasets
# All datasets are loaded directly from AWS S3:
# - `Clients.csv` - Customer information
# - `sales.csv` - Sales transactions
# - `invoices.csv` - Invoice data
# - `products.csv` - Product catalog
#
# ## Instructions
# Complete all tasks and provide insights and recommendations for each customer segment.

# %% [markdown]
# ## Task 1: Load and Explore Data
# Load all required datasets and explore their structure

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %matplotlib inline

# %%
# S3 base URL
base_url = 'https://mysiterobert.s3.us-east-1.amazonaws.com/Dataframes/'

# Load datasets from S3
clients = pd.read_csv(base_url + 'Clients.csv')
sales = pd.read_csv(base_url + 'sales.csv')
invoices = pd.read_csv(base_url + 'invoices.csv')
products = pd.read_csv(base_url + 'products.csv')

# Display first rows
print("Clients:")
display(clients.head())
print("\nSales:")
display(sales.head())
print("\nInvoices:")
display(invoices.head())
print("\nProducts:")
display(products.head())

# %% [markdown]
# ## Task 2: Data Integration
# Merge/join the datasets to create a comprehensive sales dataset with:
# - Customer information
# - Invoice details
# - Product information
# - Sales amounts

# %%
# Merge datasets

# %% [markdown]
# ## Task 3: Calculate RFM Metrics
# Calculate Recency, Frequency, and Monetary values for each customer

# %%
# Calculate RFM

# %% [markdown]
# ## Task 4: Create RFM Scores and Segments
# Assign scores and create meaningful customer segments

# %%
# Create scores and segments

# %% [markdown]
# ## Task 5: Segment Analysis and Visualization
# Analyze and visualize your customer segments

# %%
# Analysis and visualization

# %% [markdown]
# ## Task 6: Marketing Recommendations
# Provide specific marketing recommendations for each segment:
# - Champions
# - Loyal Customers
# - Potential Loyalists
# - At Risk
# - Lost Customers
#
# Include:
# - Target strategy
# - Recommended actions
# - Expected outcomes

# %% [markdown]
# ### Your recommendations here:
# ...
