# %% [markdown]
# # RFM Segmentation Workshop - Activity
#
# ## Objective
# Learn and apply RFM (Recency, Frequency, Monetary) analysis to segment customers based on their purchasing behavior.
#
# ## What is RFM Analysis?
# RFM analysis is a marketing technique used to segment customers based on three dimensions:
# - **Recency**: How recently did the customer make a purchase?
# - **Frequency**: How often do they purchase?
# - **Monetary**: How much do they spend?
#
# ## Dataset
# The dataset is loaded directly from AWS S3.
#
# **NOTE**: The main dataset is also available on Kaggle: https://www.kaggle.com/datasets/holaholap/drinks-sales-dataset

# %% [markdown]
# ## Task 1: Setup and Load Data

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta

# %matplotlib inline

# %%
# Load the dataset from S3
url = 'https://mysiterobert.s3.us-east-1.amazonaws.com/Dataframes/sales_drinks.csv'
df = pd.read_csv(url)

print(f"Dataset loaded: {df.shape[0]:,} rows × {df.shape[1]} columns")
df.head()

# %% [markdown]
# ## Task 2: Data Preparation
# - Convert purchase_datetime to datetime format
# - Define a reference date (use the maximum date + 1 day)
# - Prepare the data for RFM calculation

# %%
# Data preparation

# %% [markdown]
# ## Task 3: Calculate RFM Metrics
# For each customer, calculate:
# 1. **Recency**: Days since last purchase (reference_date - max_purchase_date)
# 2. **Frequency**: Number of unique purchases/invoices
# 3. **Monetary**: Total amount spent
#
# Create a DataFrame with customer_id and RFM metrics

# %%
# Calculate RFM metrics

# %% [markdown]
# ## Task 4: Assign RFM Scores
# Create scores (1-5) for each metric using quantiles:
# - R_Score: 5 = most recent, 1 = least recent (reverse order)
# - F_Score: 5 = most frequent, 1 = least frequent
# - M_Score: 5 = highest spending, 1 = lowest spending
#
# Use `pd.qcut()` with 5 quantiles

# %%
# Assign RFM scores

# %% [markdown]
# ## Task 5: Create RFM Segments
# Combine the three scores to create customer segments:
# - Create an RFM_Score column (concatenate R, F, M scores)
# - Define segment rules based on RFM scores
#
# Example segments:
# - **Champions**: R=5, F=5, M=5
# - **Loyal Customers**: R=4-5, F=4-5, M=4-5
# - **Potential Loyalists**: R=4-5, F=2-3, M=2-3
# - **At Risk**: R=2-3, F=2-3, M=4-5
# - **Lost**: R=1-2, F=1-2, M=1-5

# %%
# Create segments

# %% [markdown]
# ## Task 6: Analyze Segments
# For each segment, calculate:
# - Number of customers
# - Percentage of total customers
# - Average Recency, Frequency, Monetary
# - Total revenue contribution

# %%
# Segment analysis

# %% [markdown]
# ## Task 7: Visualize Segments
# Create visualizations:
# 1. Segment distribution (bar chart)
# 2. Revenue by segment (bar chart)
# 3. RFM scatter plots (R vs F, R vs M, F vs M)
# 4. Segment profile heatmap

# %%
# Visualizations

# %% [markdown]
# ## Task 8: Customer Segment Profiles
# Create detailed profiles for key segments:
# - Champions
# - At Risk
# - Lost Customers
#
# Include recommendations for each segment

# %%
# Segment profiles

# %% [markdown]
# ## Task 9: Export Segments
# Export customer segments to CSV files for marketing campaigns (optional)

# %%
# Export segments (optional)
# Example: champions.to_csv('champions_segment.csv', index=False)

# %% [markdown]
# ## Task 10: Insights and Recommendations
# Write your findings and marketing recommendations for each segment

# %% [markdown]
# ### Your insights here:
# ...
