# %% [markdown]
# # Exploratory Data Analysis: Beverage Sales Dataset - Activity
#
# ## Objective
# Perform a comprehensive exploratory data analysis of beverage sales data to uncover patterns, trends, and insights.
#
# ## Dataset
# The dataset is loaded directly from AWS S3 - over 1.8M transactions!
#
# **NOTE**: The main dataset is also available on Kaggle: https://www.kaggle.com/datasets/holaholap/drinks-sales-dataset
#
# ## Instructions
# Complete all tasks following the structure provided. Create visualizations and document your findings.

# %% [markdown]
# ## Task 1: Setup and Data Loading

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import warnings

warnings.filterwarnings('ignore')
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette('Set2')
# %matplotlib inline

# %%
# Load the dataset from S3
url = 'https://mysiterobert.s3.us-east-1.amazonaws.com/Dataframes/sales_drinks.csv'
df = pd.read_csv(url)

print(f"Dataset loaded: {df.shape[0]:,} rows × {df.shape[1]} columns")
df.head()

# %% [markdown]
# ## Task 2: Dataset Overview
# Explore the dataset structure:
# - Display shape and first rows
# - Check data types
# - Get descriptive statistics

# %%
# Dataset overview code

# %% [markdown]
# ## Task 3: Data Quality Assessment
# - Check for missing values
# - Check for duplicates
# - Validate data quality (negative values, outliers)
# - Count unique values for key columns

# %%
# Data quality assessment

# %% [markdown]
# ## Task 4: Feature Engineering
# Extract datetime features from purchase_datetime:
# - Date
# - Year, Month, Day
# - Hour
# - Day of week
# - Weekday name

# %%
# Feature engineering

# %% [markdown]
# ## Task 5: Sales Performance Summary
# Calculate and display:
# - Total revenue
# - Total transactions
# - Total items sold
# - Average transaction value
# - Average items per transaction
# - Average unit price

# %%
# Sales performance metrics

# %% [markdown]
# ## Task 6: Univariate Analysis
# Create distributions for:
# - Quantity
# - Unit price
# - Transaction amount
# - Discount percentage
# - Hour of purchase
#
# Use histograms and boxplots

# %%
# Univariate analysis

# %% [markdown]
# ## Task 7: Temporal Analysis
# Analyze sales over time:
# 1. Daily sales trend (revenue, transactions, items)
# 2. Sales by day of week
# 3. Sales by hour of day
#
# Create line charts and bar charts

# %%
# Temporal analysis

# %% [markdown]
# ## Task 8: Product Analysis
# - Top 20 products by revenue
# - Top 20 products by units sold
# - Product performance metrics
#
# Create horizontal bar charts

# %%
# Product analysis

# %% [markdown]
# ## Task 9: Category & Brand Analysis
# Analyze performance by:
# - Category (revenue, units, avg price)
# - Brand (top 15 brands)
#
# Create bar charts and pie charts

# %%
# Category and brand analysis

# %% [markdown]
# ## Task 10: Customer Analysis
# Analyze customer behavior:
# - Number of purchases per customer
# - Total spent per customer
# - Average order value
# - Top 20 customers
#
# Create distributions and rankings

# %%
# Customer analysis

# %% [markdown]
# ## Task 11: Discount Analysis
# - Calculate discount statistics
# - Compare sales with/without discounts
# - Analyze discount impact by category
#
# Create comparison charts

# %%
# Discount analysis

# %% [markdown]
# ## Task 12: Correlation Analysis
# - Create correlation matrix
# - Create scatter plots for key relationships
# - Analyze relationships between variables

# %%
# Correlation analysis

# %% [markdown]
# ## Task 13: Key Insights Summary
# Summarize your findings:
# 1. Overall performance
# 2. Category insights
# 3. Brand insights
# 4. Customer insights
# 5. Temporal insights
# 6. Discount insights
# 7. Product insights

# %%
# Key insights summary
