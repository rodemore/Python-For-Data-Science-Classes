# %% [markdown]
# # Data Cleaning Workshop - Activity
#
# ## Objective
# Practice data cleaning techniques using the employees dataset.
#
# ## Dataset
# The dataset is loaded directly from AWS S3. No download required!
#
# ## Instructions
# 1. Load the `employees_workshop.csv` dataset from S3
# 2. Identify and handle data quality issues
# 3. Clean and transform the data for analysis
# 4. Document all your cleaning steps

# %% [markdown]
# ## Task 1: Import Libraries and Load Data

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset from S3
url = 'https://mysiterobert.s3.us-east-1.amazonaws.com/Dataframes/employees_workshop.csv'
df = pd.read_csv(url)
df.head()

# %% [markdown]
# ## Task 2: Initial Data Exploration
# Explore the dataset to understand its structure and identify issues:
# - Check the shape
# - Display first/last rows
# - Check data types
# - Look for missing values
# - Check for duplicates

# %%
# Data exploration code

# %% [markdown]
# ## Task 3: Handle Missing Values
# Identify and handle missing values appropriately:
# - Count missing values per column
# - Decide on a strategy for each column (fill, drop, etc.)
# - Apply your chosen strategy

# %%
# Handle missing values

# %% [markdown]
# ## Task 4: Handle Duplicates
# - Check for duplicate rows
# - Remove duplicates if necessary
# - Document your decision

# %%
# Handle duplicates

# %% [markdown]
# ## Task 5: Data Type Corrections
# - Ensure all columns have the correct data type
# - Convert date columns to datetime format
# - Convert numeric columns if needed

# %%
# Data type corrections

# %% [markdown]
# ## Task 6: Outlier Detection
# - Identify potential outliers in numeric columns
# - Use boxplots or statistical methods
# - Decide how to handle outliers

# %%
# Outlier detection and handling

# %% [markdown]
# ## Task 7: Final Validation
# - Verify the cleaned dataset
# - Show summary statistics
# - Display the final shape
# - Save the cleaned dataset (optional)

# %%
# Final validation
