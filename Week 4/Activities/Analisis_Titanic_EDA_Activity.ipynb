# %% [markdown]
# # Análisis Exploratorio del Dataset Titanic - Activity
#
# ## Objective
# In this activity, you will perform a complete exploratory data analysis (EDA) of the Titanic dataset to discover patterns and factors that influenced passenger survival.
#
# ## Instructions
# Complete each section following the provided structure. Use Pandas for data manipulation and Matplotlib/Seaborn for visualizations.
#
# ## Dataset
# The Titanic dataset is available through the seaborn library and contains information about passengers aboard the Titanic.

# %% [markdown]
# ## Task 1: Import Libraries
# Import the necessary libraries:
# - pandas
# - numpy
# - matplotlib.pyplot
# - seaborn
# - warnings

# %%
# Import libraries here

# %% [markdown]
# ## Task 2: Load the Dataset
# Load the Titanic dataset using `sns.load_dataset('titanic')` and explore its basic structure.

# %%
# Load the dataset

# %% [markdown]
# ## Task 3: Initial Data Exploration
# Perform initial data exploration:
# 1. Display dataset info using `.info()`
# 2. Show descriptive statistics using `.describe()`
# 3. Check for missing values
# 4. Create a heatmap to visualize missing values

# %%
# Your code here

# %% [markdown]
# ## Task 4: Data Cleaning
# Handle missing values:
# - Fill missing age values with the median
# - Fill missing embarked values with the mode
# - Document your approach

# %%
# Data cleaning code

# %% [markdown]
# ## Task 5: Univariate Analysis
# Analyze individual variables:
# 1. Survival rate (bar chart and pie chart)
# 2. Age distribution (histogram and boxplot)
# 3. Passenger class distribution
# 4. Gender distribution
# 5. Fare distribution

# %%
# Univariate analysis code

# %% [markdown]
# ## Task 6: Bivariate Analysis
# Analyze relationships between variables:
# 1. Survival by gender
# 2. Survival by class
# 3. Survival by age
# 4. Survival by family size
# 5. Create visualizations for each analysis

# %%
# Bivariate analysis code

# %% [markdown]
# ## Task 7: Multivariate Analysis
# 1. Create a correlation matrix
# 2. Create a pairplot of key variables
# 3. Analyze survival by combined factors (age groups, gender, and class)

# %%
# Multivariate analysis code

# %% [markdown]
# ## Task 8: Key Insights
# Summarize your findings:
# 1. What were the main factors influencing survival?
# 2. Which passenger groups had the highest/lowest survival rates?
# 3. What patterns did you discover in the data?

# %%
# Create a summary of key insights

# %% [markdown]
# ## Bonus Challenges
# 1. Create age groups and analyze survival rates by age group
# 2. Analyze the effect of family size on survival
# 3. Create a comprehensive dashboard visualization
# 4. Write conclusions based on your analysis

# %%
# Bonus challenges code
