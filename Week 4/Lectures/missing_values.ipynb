# %%
import pandas as pd

# %%
df = pd.read_csv("empleados_v2.csv", sep = ";")
df.isna().sum(axis = 0)
# Out:
# id_empleado               0
# sexo                      0
# edad                     50
# ciudad                   76
# departamento              0
# salario                 115
# evaluacion_desempeno      0
# modalidad                 0
# estado_civil              0
# dtype: int64
