# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('personas_clean.csv')

# %%
df.columns
# Out:
# Index(['identificacion', 'nombre', 'edad', 'altura_cm', 'peso_lb', 'sexo',
#        'salario', 'ciudad', 'fecha_registro', 'nivel_educacion', 'email',
#        'nombre_clean'],
#       dtype='object')

# %%
df[["edad", "salario"]].corr()
# Out:
#              edad   salario
# edad     1.000000 -0.003104
# salario -0.003104  1.000000
